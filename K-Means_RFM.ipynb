# %%
import socket

try:
    s = socket.create_connection(("10.114.90.5", 1433), timeout=3)
    print("SQL Server is reachable!")
except Exception as e:
    print("Connection failed:", e)
# Out:
# SQL Server is reachable!

# %%
import pandas as pd
from sqlalchemy import create_engine

username = 'ccna'
password = 'Hamed123'
server_ip = '10.114.90.5'
database = 'TelcoData'

conn_str = (
    f"mssql+pyodbc://{username}:{password}"
    f"@{server_ip}/{database}?driver=ODBC+Driver+18+for+SQL+Server&Encrypt=no"
)

engine = create_engine(conn_str)
# df = pd.read_sql("SELECT TOP 100 * FROM [WA_Fn-UseC_-Telco-Customer-Churn]", engine,)
df = pd.read_sql("SELECT * FROM [WA_Fn-UseC_-Telco-Customer-Churn]", engine,)
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0      Yes          No       1
# 1     5575-GNVDE    Male              0       No          No      34
# 2     3668-QPYBK    Male              0       No          No       2
# 3     7795-CFOCW    Male              0       No          No      45
# 4     9237-HQITU  Female              0       No          No       2
# ...          ...     ...            ...      ...         ...     ...
# 7039  2234-XADUH  Female              0      Yes         Yes      72
# 7040  4801-JZAZL  Female              0      Yes         Yes      11
# 7041  8361-LTMKD    Male              1      Yes          No       4
# 7042  3186-AJIEK    Male              0       No          No      66
# 7043  customerID  gender  SeniorCitizen  Partner  Dependents  tenure
#
#       PhoneService     MultipleLines  InternetService  OnlineSecurity  ...  \
# 0               No  No phone service              DSL              No  ...
# 1              Yes                No              DSL             Yes  ...
# 2              Yes                No              DSL             Yes  ...
# 3               No  No phone service              DSL             Yes  ...
# 4              Yes                No      Fiber optic              No  ...
# ...            ...               ...              ...             ...  ...
# 7039           Yes               Yes      Fiber optic              No  ...
# 7040            No  No phone service              DSL             Yes  ...
# 7041           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
# 7043  PhoneService     MultipleLines  InternetService  OnlineSecurity  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                   No           No           No               No
# 1                  Yes           No           No               No
# 2                   No           No           No               No
# 3                  Yes          Yes           No               No
# 4                   No           No           No               No
# ...                ...          ...          ...              ...
# 7039               Yes           No          Yes              Yes
# 7040                No           No           No               No
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
# 7043  DeviceProtection  TechSupport  StreamingTV  StreamingMovies
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 0     Month-to-month               Yes           Electronic check
# 1           One year                No               Mailed check
# 2     Month-to-month               Yes               Mailed check
# 3           One year                No  Bank transfer (automatic)
# 4     Month-to-month               Yes           Electronic check
# ...              ...               ...                        ...
# 7039        One year               Yes    Credit card (automatic)
# 7040  Month-to-month               Yes           Electronic check
# 7041  Month-to-month               Yes               Mailed check
# 7042        Two year               Yes  Bank transfer (automatic)
# 7043        Contract  PaperlessBilling              PaymentMethod
#
#       MonthlyCharges  TotalCharges  Churn
# 0              29.85         29.85     No
# 1              56.95        1889.5     No
# 2              53.85        108.15    Yes
# 3               42.3       1840.75     No
# 4               70.7        151.65    Yes
# ...              ...           ...    ...
# 7039           103.2        7362.9     No
# 7040            29.6        346.45     No
# 7041            74.4         306.6    Yes
# 7042          105.65        6844.5     No
# 7043  MonthlyCharges  TotalCharges  Churn
#
# [7044 rows x 21 columns]

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA
import matplotlib.pyplot as plt

# %%
# Assuming df is already defined with a 'tenure' column containing numeric values
current_date = pd.to_datetime("2025-08-27")

# Make sure tenure column contains numeric values and handle any non-numeric values
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')

# Convert tenure to integer before applying DateOffset
# Using fillna(0) to handle any NaN values that might result from the conversion
df['start_date'] = df['tenure'].fillna(0).apply(lambda x: current_date - pd.DateOffset(months=int(x)))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7044 entries, 0 to 7043
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7044 non-null   object
#  1   gender            7044 non-null   object
#  2   SeniorCitizen     7044 non-null   object
#  3   Partner           7044 non-null   object
#  4   Dependents        7044 non-null   object
#  5   tenure            7043 non-null   float64
#  6   PhoneService      7044 non-null   object
#  7   MultipleLines     7044 non-null   object
#  8   InternetService   7044 non-null   object
#  9   OnlineSecurity    7044 non-null   object
#  10  OnlineBackup      7044 non-null   object
#  11  DeviceProtection  7044 non-null   object
#  12  TechSupport       7044 non-null   object
#  13  StreamingTV       7044 non-null   object
#  14  StreamingMovies   7044 non-null   object
#  15  Contract          7044 non-null   object
#  16  PaperlessBilling  7044 non-null   object
#  17  PaymentMethod     7044 non-null   object
#  18  MonthlyCharges    7044 non-null   object
#  19  TotalCharges      7044 non-null   object
#  20  Churn             7044 non-null   object
#  21  start_date        7044 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(20)
# memory usage: 1.2+ MB

# %%
df['end_date'] = df['Churn'].apply(
    lambda x: current_date if x == 'No' else current_date - pd.DateOffset(months=1)
)

# %%
df['Churn'] =df['Churn'].map({'No': 0,'Yes': 1})
# X = data[['Monthly_Purchase_Count', 'Average_Purchase_Amount', 'Visit_Time_code']]

# %%
df['Churn'].unique()
# Out:
# array([ 0.,  1., nan])

# %% [markdown]
# # Encoding / creat new table

# %%
df['Contract'] =df['Contract'].map({'Month-to-month': 0,'One year': 1, 'Two year': 2})

# %%
df['gender'] =df['gender'].map({'Female': 0,'Male': 1})

# %%
new_tables = df[['Churn','Contract','MonthlyCharges','TotalCharges','gender','tenure','start_date','end_date']].copy()

# %%
new_tables
# Out:
#       Churn  Contract  MonthlyCharges  TotalCharges  gender  tenure  \
# 0       0.0       0.0           29.85         29.85     0.0     1.0
# 1       0.0       1.0           56.95        1889.5     1.0    34.0
# 2       1.0       0.0           53.85        108.15     1.0     2.0
# 3       0.0       1.0            42.3       1840.75     1.0    45.0
# 4       1.0       0.0            70.7        151.65     0.0     2.0
# ...     ...       ...             ...           ...     ...     ...
# 7039    0.0       1.0           103.2        7362.9     0.0    72.0
# 7040    0.0       0.0            29.6        346.45     0.0    11.0
# 7041    1.0       0.0            74.4         306.6     1.0     4.0
# 7042    0.0       2.0          105.65        6844.5     1.0    66.0
# 7043    NaN       NaN  MonthlyCharges  TotalCharges     NaN     NaN
#
#      start_date   end_date
# 0    2025-07-27 2025-08-27
# 1    2022-10-27 2025-08-27
# 2    2025-06-27 2025-07-27
# 3    2021-11-27 2025-08-27
# 4    2025-06-27 2025-07-27
# ...         ...        ...
# 7039 2019-08-27 2025-08-27
# 7040 2024-09-27 2025-08-27
# 7041 2025-04-27 2025-07-27
# 7042 2020-02-27 2025-08-27
# 7043 2025-08-27 2025-07-27
#
# [7044 rows x 8 columns]

# %%
new_tables.isna().sum()
# Out:
# Churn             1
# Contract          1
# MonthlyCharges    0
# TotalCharges      0
# gender            1
# tenure            1
# start_date        0
# end_date          0
# dtype: int64

# %%
new_tables.isna().sum() / new_tables.shape[0] * 100
# Out:
# Churn             0.014196
# Contract          0.014196
# MonthlyCharges    0.000000
# TotalCharges      0.000000
# gender            0.014196
# tenure            0.014196
# start_date        0.000000
# end_date          0.000000
# dtype: float64

# %%
new_tables.dropna(inplace=True)

# %%
new_tables.isna().sum()
# Out:
# Churn             0
# Contract          0
# MonthlyCharges    0
# TotalCharges      0
# gender            0
# tenure            0
# start_date        0
# end_date          0
# dtype: int64

# %%
new_tables.dtypes
# Out:
# Churn                    float64
# Contract                 float64
# MonthlyCharges            object
# TotalCharges              object
# gender                   float64
# tenure                   float64
# start_date        datetime64[ns]
# end_date          datetime64[ns]
# dtype: object

# %% [markdown]
# # convert string or object to  float64

# %%
new_tables['MonthlyCharges'] = new_tables['MonthlyCharges'].astype(float)
new_tables['TotalCharges'] = pd.to_numeric(new_tables['TotalCharges'], errors='coerce')

# %% [markdown]
# * This command shows how long the customer has been a member and how long they have not made a purchase or have unsubscribed.

# %%
from datetime import datetime

# Let's assume we have a purchase date column.and Convert date column to valid values
new_tables['end_date'] = pd.to_datetime(new_tables['end_date'], errors='coerce')

# today's date
today = pd.to_datetime('today')

# Calculate distance to date
new_tables['end_date'] = (today - new_tables['end_date']).dt.days

# %%
# Let's assume we have a purchase date column.and Convert date column to valid values
new_tables['start_date'] = pd.to_datetime(new_tables['start_date'], errors='coerce')

# today's date
today = pd.to_datetime('today')

# Calculate distance to date
new_tables['start_date'] = (today - new_tables['start_date']).dt.days

# %%
new_tables.dtypes
# Out:
# Churn             float64
# Contract          float64
# MonthlyCharges    float64
# TotalCharges      float64
# gender            float64
# tenure            float64
# start_date          int64
# end_date            int64
# dtype: object

# %%
new_tables.head()
# Out:
#    Churn  Contract  MonthlyCharges  TotalCharges  gender  tenure  start_date  \
# 0    0.0       0.0           29.85         29.85     0.0     1.0         123
# 1    0.0       1.0           56.95       1889.50     1.0    34.0        1127
# 2    1.0       0.0           53.85        108.15     1.0     2.0         153
# 3    0.0       1.0           42.30       1840.75     1.0    45.0        1461
# 4    1.0       0.0           70.70        151.65     0.0     2.0         153
#
#    end_date
# 0        92
# 1        92
# 2       123
# 3        92
# 4       123

# %%
new_tables['end_date'].min()
# Out:
# 92

# %%
new_tables.isna().sum() / new_tables.shape[0] * 100
# Out:
# Churn             0.000000
# Contract          0.000000
# MonthlyCharges    0.000000
# TotalCharges      0.156183
# gender            0.000000
# tenure            0.000000
# start_date        0.000000
# end_date          0.000000
# dtype: float64

# %%
new_tables.dropna(inplace=True)

# %%
new_tables.isna().sum() / new_tables.shape[0] * 100
# Out:
# Churn             0.0
# Contract          0.0
# MonthlyCharges    0.0
# TotalCharges      0.0
# gender            0.0
# tenure            0.0
# start_date        0.0
# end_date          0.0
# dtype: float64

# %%
new_tables.isna().sum()
# Out:
# Churn             0
# Contract          0
# MonthlyCharges    0
# TotalCharges      0
# gender            0
# tenure            0
# start_date        0
# end_date          0
# dtype: int64

# %%
print(new_tables.dtypes)
# Out:
# Churn             float64
# Contract          float64
# MonthlyCharges    float64
# TotalCharges      float64
# gender            float64
# tenure            float64
# start_date          int64
# end_date            int64
# dtype: object

# %% [markdown]
# # normalization

# %%
X_scaled = StandardScaler().fit_transform(new_tables)

# %%
from sklearn.manifold import MDS
from sklearn.manifold import Isomap
from sklearn.manifold import TSNE

# %% [markdown]
# # Dimensionality Reduction

# %%
iso = Isomap(n_neighbors=10,n_components=2)
X_2d_iso = iso.fit_transform(X_scaled)
# Out:
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\sklearn\manifold\_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 11 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_2d_iso[:,0], X_2d_iso[:,1], color='gray', alpha=0.6)
plt.xlabel('Isomap 1')
plt.ylabel('Isomap 2')
plt.title('Customer Data After Dimensionality Reduction(Isomap)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_2d_iso[:,0], X_2d_iso[:,1],c=new_tables['Churn'], cmap='coolwarm')
plt.xlabel('Isomap 1')
plt.ylabel('Isomap 2')
plt.title('coustomer data after Dimensionality Reduction')
plt.colorbar(label ='visit time(0=morning,1=evening)')
plt.grid(True)
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1],c=new_tables['Churn'], cmap='coolwarm')
plt.xlabel('pca1')
plt.ylabel('pca2')
plt.title('coustomer data afterDimensionality Reduction')
plt.colorbar(label ='visit time(0=morning,1=evening)')
plt.grid(True)
plt.show()

# %%
tsne = TSNE(n_components=2)
X_2d_tsne = tsne.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_2d_tsne[:,0], X_2d_tsne[:,1], color='gray', alpha=0.6)
plt.xlabel('TSNE 1')
plt.ylabel('TSNE 2')
plt.title('Customer Data After Dimensionality Reduction')
plt.grid(True)
plt.show()

# %%
X_2d_tsne.shape
# Out:
# (7032, 2)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_2d_tsne[:,0], X_2d_tsne[:,1],c=new_tables['Churn'], cmap='coolwarm')
plt.xlabel('TSNE1')
plt.ylabel('TSNE2')
plt.title('coustomer data after pca')
plt.colorbar(label ='visit time(0=morning,1=evening)')
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import trustworthiness

# %% [markdown]
# * The accuracy evaluation of dimensionality reduction algorithms is closer to 1, which means that dimensionality reduction is more reliable and the data is well preserved. Otherwise, the neighborhood relationships are broken.

# %%
score_X_pca = trustworthiness(new_tables, X_pca, n_neighbors=5)
score_X_2d_tsne = trustworthiness(new_tables, X_2d_tsne, n_neighbors=5)
score_X_2d_iso = trustworthiness(new_tables, X_2d_iso, n_neighbors=5)
print(score_X_pca)
print(score_X_2d_tsne)
print(score_X_2d_iso)
# Out:
# 0.9870507965862533
# 0.9898163553012457
# 0.9581520071926319

# %% [markdown]
# # Implementation of the algorithm

# %%
from sklearn.cluster import KMeans

# %%
kmeans  = KMeans(n_clusters=3, random_state=11).fit_predict(X_pca)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=kmeans, cmap= 'viridis')

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.cluster import MeanShift
from sklearn.cluster import Birch
from sklearn.cluster import OPTICS

# %%
k = KMeans(n_clusters=3, random_state=11).fit_predict(X_pca)
S = SpectralClustering(n_clusters=2, random_state=11).fit_predict(X_pca)
D = DBSCAN(eps=0.2, min_samples=3).fit_predict(X_pca)
A = AgglomerativeClustering(n_clusters=2).fit_predict(X_pca)
G = GaussianMixture(n_components=2).fit_predict(X_pca)
M = MeanShift(bandwidth=2).fit_predict(X_pca)
B = Birch(n_clusters=2).fit_predict(X_pca)
O = OPTICS(eps=0.2, min_samples=3).fit_predict(X_pca)
# Out:
# C:\Users\hamed\anaconda3\envs\Machin_learning\Lib\site-packages\sklearn\cluster\_optics.py:1084: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
plt.figure(figsize=(22,4))
plt.subplot(181)
plt.title('KMeans')
plt.scatter(X_pca[:,0], X_pca[:,1], c=k, cmap= 'viridis')

plt.subplot(182)
plt.title('SpectralClustering')
plt.scatter(X_pca[:,0], X_pca[:,1], c=S, cmap= 'viridis')

plt.subplot(183)
plt.title('DBSCAN')
plt.scatter(X_pca[:,0], X_pca[:,1], c=D, cmap= 'viridis')

plt.subplot(184)
plt.title('AgglomerativeClustering')
plt.scatter(X_pca[:,0], X_pca[:,1], c=A, cmap= 'viridis')

plt.subplot(185)
plt.title('GaussianMixture')
plt.scatter(X_pca[:,0], X_pca[:,1], c=G, cmap= 'viridis')

plt.subplot(186)
plt.title('MeanShift')
plt.scatter(X_pca[:,0], X_pca[:,1], c=M, cmap= 'viridis')

plt.subplot(187)
plt.title('Birch')
plt.scatter(X_pca[:,0], X_pca[:,1], c=B, cmap= 'viridis')

plt.subplot(188)
plt.title('OPTICS')
plt.scatter(X_pca[:,0], X_pca[:,1], c=O, cmap= 'viridis')

# %% [markdown]
# * Analyzing the output of different clusters

# %%
new_tables.groupby('Cluster')[['Churn', 'Contract', 'end_date', 'MonthlyCharges','TotalCharges','gender','tenure']].mean()
# Out:
#             Churn  Contract    end_date  MonthlyCharges  TotalCharges  \
# Cluster
# 0        0.001354  0.888588   92.041973       61.278743   2555.528211
# 1        1.000000  0.133190  123.000000       74.570301   1527.437084
#
#            gender     tenure
# Cluster
# 0        0.507350  37.685106
# 1        0.497315  17.807734

# %%
new_tables.head()
# Out:
#    Churn  Contract  MonthlyCharges  TotalCharges  gender  tenure  start_date  \
# 0    0.0       0.0           29.85         29.85     0.0     1.0         123
# 1    0.0       1.0           56.95       1889.50     1.0    34.0        1127
# 2    1.0       0.0           53.85        108.15     1.0     2.0         153
# 3    0.0       1.0           42.30       1840.75     1.0    45.0        1461
# 4    1.0       0.0           70.70        151.65     0.0     2.0         153
#
#    end_date  Cluster
# 0        92        0
# 1        92        0
# 2       123        1
# 3        92        0
# 4       123        1

# %%
from sklearn.metrics import adjusted_mutual_info_score

# %%
score1 = adjusted_mutual_info_score(new_tables['Churn'],k)
score2 = adjusted_mutual_info_score(new_tables['Churn'],S)
score3 = adjusted_mutual_info_score(new_tables['Churn'],D)
score4 = adjusted_mutual_info_score(new_tables['Churn'],A)
score5 = adjusted_mutual_info_score(new_tables['Churn'],G)
score6 = adjusted_mutual_info_score(new_tables['Churn'],M)
score7 = adjusted_mutual_info_score(new_tables['Churn'],B)
score8 = adjusted_mutual_info_score(new_tables['Churn'],O)

# %%
print(score1,
score2,
score3,
score4,
score5,
score6,
score7,
score8)
# Out:
# 0.6076709474089861 0.9806488750611505 0.97369294057074 1.0 0.9766265947669936 0.9877906375521117 0.9941451886394995 0.10976465800060393

# %%
# plt.scatter(X_pca[:,0], X_pca[:,1],c=M, cmap='Set1')

# %% [markdown]
# # Loyal customers are in red.

# %%
plt.figure(figsize=(22,4))
plt.subplot(181)
plt.title('KMeans')
plt.scatter(X_pca[:,0], X_pca[:,1], c=k, cmap= 'Set1')

plt.subplot(182)
plt.title('SpectralClustering')
plt.scatter(X_pca[:,0], X_pca[:,1], c=S, cmap= 'Set1')

plt.subplot(183)
plt.title('DBSCAN')
plt.scatter(X_pca[:,0], X_pca[:,1], c=D, cmap= 'Set1')

plt.subplot(184)
plt.title('AgglomerativeClustering')
plt.scatter(X_pca[:,0], X_pca[:,1], c=A, cmap= 'Set1')

plt.subplot(185)
plt.title('GaussianMixture')
plt.scatter(X_pca[:,0], X_pca[:,1], c=G, cmap= 'Set1')

plt.subplot(186)
plt.title('MeanShift')
plt.scatter(X_pca[:,0], X_pca[:,1], c=M, cmap= 'Set1')

plt.subplot(187)
plt.title('Birch')
plt.scatter(X_pca[:,0], X_pca[:,1], c=B, cmap= 'Set1')

plt.subplot(188)
plt.title('OPTICS')
plt.scatter(X_pca[:,0], X_pca[:,1], c=O, cmap= 'Set1')

# %%
import numpy as np
np.unique(O)
# Out:
# array([  -1,    0,    1, ..., 1073, 1074, 1075])

# %%
plt.figure(figsize=(22,20))
colors = ['red', 'blue', 'gray']  # red= cluster0, blue= cluster1, gray=noise
plt.scatter(X_pca[:,0], X_pca[:,1], c=[colors[i] if i!=-1 else 'gray' for i in M])

# %%
colors = []
for i in M:
    if i == -1:
        colors.append('gray')  #noise
    elif i == 0:
        colors.append('red')
    elif i == 1:
        colors.append('blue')
    elif i == 2:
        colors.append('green')

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=colors)

# %% [markdown]
# * Groups data based on clusters.
# * - That is, if the cluster column is, for example, a specific purchase month or category, each value from the cluster is a separate group.

# %%
grouped = new_tables.groupby('Cluster').agg({
    'Churn': 'mean',
    'Contract':'mean',
    'MonthlyCharges':'mean',
    'TotalCharges':'mean',
    'gender':'mean',
    'tenure':'mean',
    'start_date':'mean',
    'end_date':'mean'
    
}).reset_index()
print(grouped)
# Out:
#    Cluster     Churn  Contract  MonthlyCharges  TotalCharges    gender  \
# 0        0  0.001354  0.888588       61.278743   2555.528211  0.507350
# 1        1  1.000000  0.133190       74.570301   1527.437084  0.497315
#
#       tenure   start_date    end_date
# 0  37.685106  1239.062282   92.041973
# 1  17.807734   634.125134  123.000000

# %%
new_tables['segment'] = new_tables['Cluster'].map({
    0: 'Loyal and valuable customers',
    1: 'Lost customers'
})

# %%
new_tables['segment']
# Out:
# 0       Loyal and valuable customers
# 1       Loyal and valuable customers
# 2                     Lost customers
# 3       Loyal and valuable customers
# 4                     Lost customers
#                     ...
# 7038    Loyal and valuable customers
# 7039    Loyal and valuable customers
# 7040    Loyal and valuable customers
# 7041                  Lost customers
# 7042    Loyal and valuable customers
# Name: segment, Length: 7032, dtype: object

# %%
import numpy as np

# %%
# new_tables['segment'] = np.where(new_tables['MonthlyCharges'] >72.000000 ,'loyal_coustomer','non_loyal_coustomer')

# %%
# new_tables['segment'] = np.where(new_tables['TotalCharges'] >2000.000000 ,'loyal_coustomer','non_loyal_coustomer')

# %%
# colors= new_tables['segment'].map({
#     'loyal_coustomer':'green',
#     'non_loyal_coustomer':'gray',
    
# })

new_tables['S'] = S
colors = new_tables['S'].map({
    0: 'green',
    1: 'gray'
})

# %%
plt.figure(figsize=(26,12))
plt.scatter(X_pca[:,0], X_pca[:,1], c=colors)
plt.xlabel('pca1')
plt.ylabel('pca2')
plt.title("'green' = Loyal and valuable customers 'gray' = Lost customers")
plt.grid(True)
plt.show()

# %%
# print(new_tables.select_dtypes(include='number').nunique())

# %%
# new_tables['Cluster'].unique()

# %%
# new_tables.head()

# %%
# new_tables['end'] = new_tables['Churn'].apply(
#     lambda x: current_date if x == 0 else current_date - pd.DateOffset(months=1)
# )
